# %% [markdown]
# This code file is for converting the math latex code created by Calculator.ipynb into sympy by using sympy2latex vscode extension.\
# \
# Stage 1: Place latex terms into latex2sympy(r'[expression]'), highlight, then use ctrl+shift+alt+p. When shortcut completes, search for the equals sign since what follows will be the sympy expression.\
# \
# Stage 2: Sorting and processing. Arranged into Reck and Clements blocks, then change 'i' to 'I' and replace e.g. theta_{10} to theta_10 since sympy doesn't need the curly braces like latex.\
# \
# Stage 3: Processing to get appropriate expression for probability 'p' for HMC code. This stage is done by setting sympy symbols to real=True and using simplify(Abs(term.rewrite(sin))**2). This is since PyMC requires expressions to be real and this processing puts it into a nice format.\
# \
# Stage 4:Aggregation of sympy expressions into a decent format so i can optionally import them into my scaled HMC file. Note that this will require sympy to cooperate with PyMC otherwise i will have to write out the expressions manually (AKA more busywork).

# %%
"""
Still to do:
 - Redo Reck_4_C and Reck_4_F since there are unclosed brackets in them and so want to be safe and redo them.
    - Redone them and got the same results.
 - Finish collecting the simplification results
 - Aggregate all the expressions in markdown under stage 4
"""
# Out:
# '\nStill to do:\n - Redo Reck_4_C and Reck_4_F since there are unclosed brackets in them and so want to be safe and redo them.\n    - Redone them and got the same results.\n - Finish collecting the simplification results\n - Aggregate all the expressions in markdown under stage 4\n'

# %%
#Import modules
import latex2sympy2
import flask
#from tqdm.notebook import tqdm
from sympy import *

#symbols definition, could maybe do this like lambda expression in Calculator code?
theta_0, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10, theta_11, phi_0, phi_1, phi_2, phi_3, phi_4, phi_5, phi_6, phi_7, phi_8, phi_9, phi_10, phi_11 = symbols('theta_0 theta_1 theta_2 theta_3 theta_4 theta_5 theta_6 theta_7 theta_8 theta_9 theta_10 theta_11 phi_0 phi_1 phi_2 phi_3 phi_4 phi_5 phi_6 phi_7 phi_8 phi_9 phi_10 phi_11',real=True)
init_printing()

# %% [markdown]
# Clements

# %%
#Convert by having extension,highlighting and pressing ctrl+shift+alt+p

#N=2

#A
latex2sympy(r'\left(e^{I \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{I \phi_{1}}')
(exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
#B 
latex2sympy(r'I \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}}')
I*(exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)
#C 
latex2sympy(r'i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right)')
I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))
#D 
latex2sympy(r'- e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} + \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}')
-exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) + cos(theta_0/2)*cos(theta_1/2)

# %%
#N=3

#A
latex2sympy(r'\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}}')
((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
#B 
latex2sympy(r'i \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}}')
I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
#C
latex2sympy(r'- \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)}')
-(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))
#D 
latex2sympy(r'i \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right)')
I*((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))
#E 
latex2sympy(r'\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}')
((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2)
#F 
latex2sympy(r'i \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(- e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} + \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}}')
I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(-exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) + cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)
#G 
latex2sympy(r'- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right)')
-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
#H 
latex2sympy(r'- i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right)')
-I*(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
#I 
latex2sympy(r'- e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} + \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}')
-exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) + cos(theta_2/2)*cos(theta_3/2)

# %%
#Convert by having extension,highlighting and pressing ctrl+shift+alt+p

#N=4

#A 
latex2sympy(r'\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \cos{\left(\frac{\theta_{7}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}}')
((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*cos(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*sin(theta_7/2))*exp(I*phi_7)
#B 
latex2sympy(r'i \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \cos{\left(\frac{\theta_{7}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}}')
I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*cos(theta_7/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*sin(theta_7/2))*exp(I*phi_7)
#C 
latex2sympy(r'- \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5} + \phi_{7}\right)}')
-(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*exp(I*(phi_3 + phi_5 + phi_7))
#D 
latex2sympy(r'- i \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5} + \phi_{7}\right)}')
-I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*exp(I*(phi_3 + phi_5 + phi_7))
#E 
latex2sympy(r'i \left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \cos{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
I*(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*sin(theta_11/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*cos(theta_11/2))*exp(I*phi_11)
#F 
latex2sympy(r'\left(\left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \sin{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(- e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} + \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(- \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \cos{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(-exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) + sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*sin(theta_11/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*cos(theta_11/2))*exp(I*phi_11)
#G 
latex2sympy(r'i \left(- \left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)} + \left(- \left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
I*(-((((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) + (-(((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
#H 
latex2sympy(r'\left(\left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)} - \left(- \left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - (-(((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
#I 
latex2sympy(r'\left(\left(\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} - \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \sin{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)} + \left(\left(\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} - \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)}')
((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*cos(theta_11/2) + ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*sin(theta_11/2)
#J 
latex2sympy(r'i \left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)} + \left(- \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} - \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{6}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{6}}{2} \right)}\right) \cos{\left(\frac{\theta_{7}}{2} \right)}\right) \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} - \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)}\right)')
I*(-(((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*cos(theta_11/2) + (-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*sin(theta_11/2))
#K 
latex2sympy(r'\left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)} + \left(- \left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)}')
((((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) + (-(((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2)
#L 
latex2sympy(r'i \left(\left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} - \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)}\right)')
I*(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2))
#M 
latex2sympy(r'- i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)} \cos{\left(\frac{\theta_{8}}{2} \right)} + \sin{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)}\right)')
-I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*sin(theta_9/2)*cos(theta_8/2) + sin(theta_8/2)*cos(theta_9/2))
#N 
latex2sympy(r'\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)} + \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \left(e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)} \cos{\left(\frac{\theta_{8}}{2} \right)} + \sin{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)}\right)')
(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*sin(theta_9/2)*cos(theta_8/2) + sin(theta_8/2)*cos(theta_9/2))
#O 
latex2sympy(r'i \left(- \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \cos{\left(\frac{\theta_{9}}{2} \right)}\right)')
I*(-((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2))
#P 
latex2sympy(r'\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)} - \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \cos{\left(\frac{\theta_{9}}{2} \right)}')
((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) - ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2)

# %% [markdown]
# Reck

# %%
#Convert by having extension,highlighting and pressing ctrl+shift+alt+p

#N=2 (same as Clements)

#A 
latex2sympy(r'\left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}}')
(exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
#B 
latex2sympy(r'i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}}')
I*(exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)
#C 
latex2sympy(r'i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right)')
I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))
#D 
latex2sympy(r'- e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} + \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}')
-exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) + cos(theta_0/2)*cos(theta_1/2)

# %%
#Convert by having extension,highlighting and pressing ctrl+shift+alt+p

#N=3 (Same as Clements)

#A 
latex2sympy(r'\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}}')
((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
#B 
latex2sympy(r'i \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}}')
I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
#C 
latex2sympy(r'- \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)}')
-(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))
#D 
latex2sympy(r'i \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right)')
I*((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))
#E 
latex2sympy(r'\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}')
((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2)
#F 
latex2sympy(r'i \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(- e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} + \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}}')
I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(-exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) + cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)
#G 
latex2sympy(r'- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right)')
-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
#H 
latex2sympy(r'- i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right)')
-I*(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
#I 
latex2sympy(r' - e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} + \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}')
-exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) + cos(theta_2/2)*cos(theta_3/2)

# %%
#Convert by having extension,highlighting and pressing ctrl+shift+alt+p

#N=4

#A 
latex2sympy(r'\left(\left(- \left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
((-(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - ((-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
#B 
latex2sympy(r'i \left(\left(- \left(\left(- \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(- e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(- e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(\left(- \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(- e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(- e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
I*((-((-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - (((-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
#C 
latex2sympy(r' - \left(- \left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} - \left(- \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \cos{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} - \left(- \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \sin{\left(\frac{\theta_{11}}{2} \right)}\right) e^{i \phi_{11}}')
-(-((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - (-(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - (-(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
#D 
latex2sympy(r'- i \left(e^{i \phi_{10}} \sin{\left(\frac{\theta_{10}}{2} \right)} \cos{\left(\frac{\theta_{11}}{2} \right)} + \sin{\left(\frac{\theta_{11}}{2} \right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) \left(e^{i \phi_{8}} \sin{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} + \sin{\left(\frac{\theta_{9}}{2} \right)} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \left(\phi_{11} + \phi_{7} + \phi_{9}\right)}')
-I*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(exp(I*phi_8)*sin(theta_8/2)*cos(theta_9/2) + sin(theta_9/2)*cos(theta_8/2))*(exp(I*phi_10)*sin(theta_10/2)*cos(theta_11/2) + sin(theta_11/2)*cos(theta_10/2))*exp(I*(phi_7 + phi_9 + phi_11))
#E 
latex2sympy(r'i \left(\left(- \left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)} + \left(\left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)}\right)')
I*((-(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) + ((-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*cos(theta_11/2))
#F 
latex2sympy(r'\left(\left(\left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} - \left(\left(- \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} + \left(\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(\left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} - \left(\left(- \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} - \left(\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \cos{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \sin{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{5}} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)}')
(((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - (((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) - (((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*cos(theta_11/2)
#G 
latex2sympy(r'i \left(\left(\left(\left(\left(e^{i \phi_{2}}\sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \sin{\left(\frac{\theta_{10}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \cos{\left(\frac{\theta_{10}}{2} \right)}\right) e^{i \phi_{10}} \sin{\left(\frac{\theta_{11}}{2} \right)} - \left(\left(\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \sin{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{9}} \cos{\left(\frac{\theta_{10}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)} + \sin{\left(\frac{\theta_{5}}{2} \right)} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \left(\phi_{3} + \phi_{5}\right)} \sin{\left(\frac{\theta_{10}}{2} \right)}\right) \cos{\left(\frac{\theta_{11}}{2} \right)}\right)')
I*(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2))
#H 
latex2sympy(r'\left(e^{i \phi_{10}} \sin{\left(\frac{\theta_{10}}{2} \right)} \sin{\left(\frac{\theta_{11}}{2} \right)} - \cos{\left(\frac{\theta_{10}}{2} \right)} \cos{\left(\frac{\theta_{11}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) \left(e^{i \phi_{8}} \sin{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)} + \sin{\left(\frac{\theta_{9}}{2} \right)} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \left(\phi_{7} + \phi_{9}\right)}')
(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(exp(I*phi_8)*sin(theta_8/2)*cos(theta_9/2) + sin(theta_9/2)*cos(theta_8/2))*(exp(I*phi_10)*sin(theta_10/2)*sin(theta_11/2) - cos(theta_10/2)*cos(theta_11/2))*exp(I*(phi_7 + phi_9))
#I 
latex2sympy(r'\left(\left(\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(\left(\left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} - \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} - \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} - \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)}')
((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*cos(theta_9/2) + ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*sin(theta_9/2)
#J 
latex2sympy(r'i \left(- \left(\left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) \cos{\left(\frac{\theta_{9}}{2} \right)} + \left(- \left(\left(- \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \cos{\left(\frac{\theta_{4}}{2} \right)}\right) e^{i \phi_{4}} \sin{\left(\frac{\theta_{5}}{2} \right)} + \left(\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} - \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{4}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)} + \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)}\right) e^{i \phi_{1}} \sin{\left(\frac{\theta_{4}}{2} \right)}\right) \cos{\left(\frac{\theta_{5}}{2} \right)}\right) \cos{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)}\right)')
I*(-(((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*cos(theta_9/2) + (-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*sin(theta_9/2))
#K 
latex2sympy(r'\left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \sin{\left(\frac{\theta_{8}}{2} \right)} + \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \cos{\left(\frac{\theta_{8}}{2} \right)}\right) e^{i \phi_{8}} \sin{\left(\frac{\theta_{9}}{2} \right)} - \left(\left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} - \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)}\right) e^{i \phi_{7}} \cos{\left(\frac{\theta_{8}}{2} \right)} - \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)} + \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)}\right) \left(e^{i \phi_{4}} \sin{\left(\frac{\theta_{4}}{2} \right)} \sin{\left(\frac{\theta_{5}}{2} \right)} - \cos{\left(\frac{\theta_{4}}{2} \right)} \cos{\left(\frac{\theta_{5}}{2} \right)}\right) e^{i \phi_{3}} \sin{\left(\frac{\theta_{8}}{2} \right)}\right) \cos{\left(\frac{\theta_{9}}{2} \right)}')
((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) - ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2)
#L 
latex2sympy(r'i \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)} + \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)}\right) \left(- e^{i \phi_{8}} \sin{\left(\frac{\theta_{8}}{2} \right)} \sin{\left(\frac{\theta_{9}}{2} \right)} + \cos{\left(\frac{\theta_{8}}{2} \right)} \cos{\left(\frac{\theta_{9}}{2} \right)}\right) e^{i \phi_{7}}')
I*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(-exp(I*phi_8)*sin(theta_8/2)*sin(theta_9/2) + cos(theta_8/2)*cos(theta_9/2))*exp(I*phi_7)
#M 
latex2sympy(r'- i \left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{1}}{2} \right)} \cos{\left(\frac{\theta_{0}}{2} \right)} + \sin{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right)')
-I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
#N 
latex2sympy(r'\left(e^{i \phi_{0}} \sin{\left(\frac{\theta_{0}}{2} \right)} \sin{\left(\frac{\theta_{1}}{2} \right)} - \cos{\left(\frac{\theta_{0}}{2} \right)} \cos{\left(\frac{\theta_{1}}{2} \right)}\right) \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{3}}{2} \right)} \cos{\left(\frac{\theta_{2}}{2} \right)} + \sin{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right)')
(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
#O 
latex2sympy(r'- i \left(e^{i \phi_{2}} \sin{\left(\frac{\theta_{2}}{2} \right)} \sin{\left(\frac{\theta_{3}}{2} \right)} - \cos{\left(\frac{\theta_{2}}{2} \right)} \cos{\left(\frac{\theta_{3}}{2} \right)}\right) \left(e^{i \phi_{6}} \sin{\left(\frac{\theta_{7}}{2} \right)} \cos{\left(\frac{\theta_{6}}{2} \right)} + \sin{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}\right)')
-I*(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
#P 
latex2sympy(r'- e^{i \phi_{6}} \sin{\left(\frac{\theta_{6}}{2} \right)} \sin{\left(\frac{\theta_{7}}{2} \right)} + \cos{\left(\frac{\theta_{6}}{2} \right)} \cos{\left(\frac{\theta_{7}}{2} \right)}')
-exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) + cos(theta_6/2)*cos(theta_7/2)

# %% [markdown]
# -------
# Stage 2
# -------

# %% [markdown]
# All sympy expressions

# %% [markdown]
# -------
# Stage 1
# -------

# %%
#Copy output into a sympy expression explicitly
#N.B. Need to replace 'i' with 'I' and remove {} for multicharacter subscript, done manually or using find & replace.

from sympy import *

#symbols definition, could maybe do this like lambda expression in Calculator code?
theta_0, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10, theta_11, phi_0, phi_1, phi_2, phi_3, phi_4, phi_5, phi_6, phi_7, phi_8, phi_9, phi_10, phi_11 = symbols('theta_0 theta_1 theta_2 theta_3 theta_4 theta_5 theta_6 theta_7 theta_8 theta_9 theta_10 theta_11 phi_0 phi_1 phi_2 phi_3 phi_4 phi_5 phi_6 phi_7 phi_8 phi_9 phi_10 phi_11',real=True)
init_printing()

#Clements

#N=2
Clements_2_A = (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
Clements_2_B = I*(exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)
Clements_2_C = I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))
Clements_2_D = -exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) + cos(theta_0/2)*cos(theta_1/2)

#N=3
Clements_3_A = ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Clements_3_B = I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Clements_3_C = -(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))
Clements_3_D = I*((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))
Clements_3_E = ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2)
Clements_3_F = I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(-exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) + cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)
Clements_3_G = -(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Clements_3_H = -I*(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Clements_3_I = -exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) + cos(theta_2/2)*cos(theta_3/2)

#N=4
Clements_4_A = ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*cos(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*sin(theta_7/2))*exp(I*phi_7)
Clements_4_B = I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*cos(theta_7/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*sin(theta_7/2))*exp(I*phi_7)
Clements_4_C = -(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*exp(I*(phi_3 + phi_5 + phi_7))
Clements_4_D = -I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*exp(I*(phi_3 + phi_5 + phi_7))
Clements_4_E = I*(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*sin(theta_11/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*cos(theta_11/2))*exp(I*phi_11)
Clements_4_F = ((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(-exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) + sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*sin(theta_11/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*cos(theta_11/2))*exp(I*phi_11)
Clements_4_G = I*(-((((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) + (-(((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Clements_4_H = (((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - (-(((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Clements_4_I = ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*cos(theta_11/2) + ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*sin(theta_11/2)
Clements_4_J = I*(-(((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*cos(theta_11/2) + (-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*sin(theta_11/2))
Clements_4_K = ((((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) + (-(((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2)
Clements_4_L = I*(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2))
Clements_4_M = -I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*sin(theta_9/2)*cos(theta_8/2) + sin(theta_8/2)*cos(theta_9/2))
Clements_4_N = (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*sin(theta_9/2)*cos(theta_8/2) + sin(theta_8/2)*cos(theta_9/2))
Clements_4_O = I*(-((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2))
Clements_4_P = ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) - ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2)

#Reck

#N=2
Reck_2_A = (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
Reck_2_B = I*(exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)
Reck_2_C = I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))
Reck_2_D = -exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) + cos(theta_0/2)*cos(theta_1/2)

#N=3
Reck_3_A = ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Reck_3_B = I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Reck_3_C = -(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))
Reck_3_D = I*((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))
Reck_3_E = ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2)
Reck_3_F = I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(-exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) + cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)
Reck_3_G = -(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Reck_3_H = -I*(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Reck_3_I = -exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) + cos(theta_2/2)*cos(theta_3/2)

#N=4
Reck_4_A = ((-(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - ((-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Reck_4_B = I*((-((-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - (((-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Reck_4_C = -(-((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - (-(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - (-(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Reck_4_D = -I*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(exp(I*phi_8)*sin(theta_8/2)*cos(theta_9/2) + sin(theta_9/2)*cos(theta_8/2))*(exp(I*phi_10)*sin(theta_10/2)*cos(theta_11/2) + sin(theta_11/2)*cos(theta_10/2))*exp(I*(phi_7 + phi_9 + phi_11))
Reck_4_E = I*((-(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) + ((-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*cos(theta_11/2))
Reck_4_F = (((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - (((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) - (((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*cos(theta_11/2)
Reck_4_G = I*(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2))
Reck_4_H = (exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(exp(I*phi_8)*sin(theta_8/2)*cos(theta_9/2) + sin(theta_9/2)*cos(theta_8/2))*(exp(I*phi_10)*sin(theta_10/2)*sin(theta_11/2) - cos(theta_10/2)*cos(theta_11/2))*exp(I*(phi_7 + phi_9))
Reck_4_I = ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*cos(theta_9/2) + ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*sin(theta_9/2)
Reck_4_J = I*(-(((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*cos(theta_9/2) + (-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*sin(theta_9/2))
Reck_4_K = ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) - ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2)
Reck_4_L = I*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(-exp(I*phi_8)*sin(theta_8/2)*sin(theta_9/2) + cos(theta_8/2)*cos(theta_9/2))*exp(I*phi_7)
Reck_4_M = -I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
Reck_4_N = (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
Reck_4_O = -I*(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
Reck_4_P = -exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) + cos(theta_6/2)*cos(theta_7/2)

# %% [markdown]
# -------
# Stage 3
# -------

# %% [markdown]
# Clements

# %%
#Postprocess to get 'p' expressions for PyMC

#N=2
Clements_2_A_res = simplify(Abs(Clements_2_A.rewrite(sin))**2)
Clements_2_B_res = simplify(Abs(Clements_2_B.rewrite(sin))**2)
Clements_2_C_res = simplify(Abs(Clements_2_C.rewrite(sin))**2)
Clements_2_D_res = simplify(Abs(Clements_2_D.rewrite(sin))**2)

display(Clements_2_A_res)
display(Clements_2_B_res)
display(Clements_2_C_res)
display(Clements_2_D_res)

# %% [markdown]
# Results:
#
#
# A:\
# \
# $\displaystyle - \frac{\sin{\left(\theta_{0} \right)} \sin{\left(\theta_{1} \right)} \cos{\left(\phi_{0} \right)}}{2} + \frac{\cos{\left(\theta_{0} \right)} \cos{\left(\theta_{1} \right)}}{2} + \frac{1}{2}$
#
# B:\
# \
# $\displaystyle \frac{\sin{\left(\theta_{0} \right)} \sin{\left(\theta_{1} \right)} \cos{\left(\phi_{0} \right)}}{2} - \frac{\cos{\left(\theta_{0} \right)} \cos{\left(\theta_{1} \right)}}{2} + \frac{1}{2}$
#
# C:\
# \
# $\displaystyle - \frac{\cos{\left(\theta_{0} - \theta_{1} \right)}}{4} - \frac{\cos{\left(\theta_{0} + \theta_{1} \right)}}{4} - \frac{\cos{\left(- \phi_{0} + \theta_{0} + \theta_{1} \right)}}{8} + \frac{\cos{\left(\phi_{0} - \theta_{0} + \theta_{1} \right)}}{8} + \frac{\cos{\left(\phi_{0} + \theta_{0} - \theta_{1} \right)}}{8} - \frac{\cos{\left(\phi_{0} + \theta_{0} + \theta_{1} \right)}}{8} + \frac{1}{2}$
#
# D:\
# \
# $\displaystyle \frac{\cos{\left(\theta_{0} - \theta_{1} \right)}}{4} + \frac{\cos{\left(\theta_{0} + \theta_{1} \right)}}{4} + \frac{\cos{\left(- \phi_{0} + \theta_{0} + \theta_{1} \right)}}{8} - \frac{\cos{\left(\phi_{0} - \theta_{0} + \theta_{1} \right)}}{8} - \frac{\cos{\left(\phi_{0} + \theta_{0} - \theta_{1} \right)}}{8} + \frac{\cos{\left(\phi_{0} + \theta_{0} + \theta_{1} \right)}}{8} + \frac{1}{2}$

# %%
#Clements_3_A_res = simplify(Abs(Clements_3_A.rewrite(sin))**2)

#term=Clements_3_A.rewrite(sin) #2.8s
#display(term)
#term2=term.expand() #12.3s
#display(term2)
#term3=Abs(term2)
#display(term3) #21m

term=Clements_3_A.rewrite(sin) #2.8s
#display(term)
term2=Abs(term) #4m2
#display(term2)
term3=term2.expand() #5m40
#display(term3)
term4=term3**2 #10m24
display(term4)
#term3=simplify(term2) #doesn't speed things up
#term3=term2**2 #Too many terms to expand i think so also impractically slow :(
#fin=simplify(term2)

#display(Clements_3_A_res)
#display(term)
#display(term2)
#display(term3)
#display(fin)

# %%
#N=3
Clements_3_A_res = simplify(Abs(Clements_3_A.rewrite(sin))**2)
Clements_3_B_res = simplify(Abs(Clements_3_B.rewrite(sin))**2)
Clements_3_C_res = simplify(Abs(Clements_3_C.rewrite(sin))**2)
Clements_3_D_res = simplify(Abs(Clements_3_D.rewrite(sin))**2)
Clements_3_E_res = simplify(Abs(Clements_3_E.rewrite(sin))**2)
Clements_3_F_res = simplify(Abs(Clements_3_F.rewrite(sin))**2)
Clements_3_G_res = simplify(Abs(Clements_3_G.rewrite(sin))**2)
Clements_3_H_res = simplify(Abs(Clements_3_H.rewrite(sin))**2)
Clements_3_I_res = simplify(Abs(Clements_3_I.rewrite(sin))**2)

display(Clements_3_A_res)
display(Clements_3_B_res)
display(Clements_3_C_res)
display(Clements_3_D_res)
display(Clements_3_E_res)
display(Clements_3_F_res)
display(Clements_3_G_res)
display(Clements_3_H_res)
display(Clements_3_I_res)

# %%
#N=4

Clements_4_A_res = simplify(Abs(Clements_4_A.rewrite(sin))**2)
Clements_4_B_res = simplify(Abs(Clements_4_B.rewrite(sin))**2)
Clements_4_C_res = simplify(Abs(Clements_4_C.rewrite(sin))**2)
Clements_4_D_res = simplify(Abs(Clements_4_D.rewrite(sin))**2)
Clements_4_E_res = simplify(Abs(Clements_4_E.rewrite(sin))**2)
Clements_4_F_res = simplify(Abs(Clements_4_F.rewrite(sin))**2)
Clements_4_G_res = simplify(Abs(Clements_4_G.rewrite(sin))**2)
Clements_4_H_res = simplify(Abs(Clements_4_H.rewrite(sin))**2)
Clements_4_I_res = simplify(Abs(Clements_4_I.rewrite(sin))**2)
Clements_4_J_res = simplify(Abs(Clements_4_J.rewrite(sin))**2)
Clements_4_K_res = simplify(Abs(Clements_4_K.rewrite(sin))**2)
Clements_4_L_res = simplify(Abs(Clements_4_L.rewrite(sin))**2)
Clements_4_M_res = simplify(Abs(Clements_4_M.rewrite(sin))**2)
Clements_4_N_res = simplify(Abs(Clements_4_N.rewrite(sin))**2)
Clements_4_O_res = simplify(Abs(Clements_4_O.rewrite(sin))**2)
Clements_4_P_res = simplify(Abs(Clements_4_P.rewrite(sin))**2)

display(Clements_4_A_res)
display(Clements_4_B_res)
display(Clements_4_C_res)
display(Clements_4_D_res)
display(Clements_4_E_res)
display(Clements_4_F_res)
display(Clements_4_G_res)
display(Clements_4_H_res)
display(Clements_4_I_res)
display(Clements_4_J_res)
display(Clements_4_K_res)
display(Clements_4_L_res)
display(Clements_4_M_res)
display(Clements_4_N_res)
display(Clements_4_O_res)
display(Clements_4_P_res)

# %% [markdown]
# Reck

# %%
#N=2
Reck_2_A_res = simplify(Abs(Reck_2_A.rewrite(sin))**2)
Reck_2_B_res = simplify(Abs(Reck_2_B.rewrite(sin))**2)
Reck_2_C_res = simplify(Abs(Reck_2_C.rewrite(sin))**2)
Reck_2_D_res = simplify(Abs(Reck_2_D.rewrite(sin))**2)

display(Reck_2_A_res)
display(Reck_2_B_res)
display(Reck_2_C_res)
display(Reck_2_D_res)

# %%
#N=3
Reck_3_A_res = simplify(Abs(Reck_3_A.rewrite(sin))**2)
Reck_3_B_res = simplify(Abs(Reck_3_B.rewrite(sin))**2)
Reck_3_C_res = simplify(Abs(Reck_3_C.rewrite(sin))**2)
Reck_3_D_res = simplify(Abs(Reck_3_D.rewrite(sin))**2)
Reck_3_E_res = simplify(Abs(Reck_3_E.rewrite(sin))**2)
Reck_3_F_res = simplify(Abs(Reck_3_F.rewrite(sin))**2)
Reck_3_G_res = simplify(Abs(Reck_3_G.rewrite(sin))**2)
Reck_3_H_res = simplify(Abs(Reck_3_H.rewrite(sin))**2)
Reck_3_I_res = simplify(Abs(Reck_3_I.rewrite(sin))**2)

display(Reck_3_A_res)
display(Reck_3_B_res)
display(Reck_3_C_res)
display(Reck_3_D_res)
display(Reck_3_E_res)
display(Reck_3_F_res)
display(Reck_3_G_res)
display(Reck_3_H_res)
display(Reck_3_I_res)

# %%
#N=4
Reck_4_A_res = simplify(Abs(Reck_4_A.rewrite(sin))**2)
Reck_4_B_res = simplify(Abs(Reck_4_B.rewrite(sin))**2)
Reck_4_C_res = simplify(Abs(Reck_4_C.rewrite(sin))**2)
Reck_4_D_res = simplify(Abs(Reck_4_D.rewrite(sin))**2)
Reck_4_E_res = simplify(Abs(Reck_4_E.rewrite(sin))**2)
Reck_4_F_res = simplify(Abs(Reck_4_F.rewrite(sin))**2)
Reck_4_G_res = simplify(Abs(Reck_4_G.rewrite(sin))**2)
Reck_4_H_res = simplify(Abs(Reck_4_H.rewrite(sin))**2)
Reck_4_I_res = simplify(Abs(Reck_4_I.rewrite(sin))**2)
Reck_4_J_res = simplify(Abs(Reck_4_J.rewrite(sin))**2)
Reck_4_K_res = simplify(Abs(Reck_4_K.rewrite(sin))**2)
Reck_4_L_res = simplify(Abs(Reck_4_L.rewrite(sin))**2)
Reck_4_M_res = simplify(Abs(Reck_4_M.rewrite(sin))**2)
Reck_4_N_res = simplify(Abs(Reck_4_N.rewrite(sin))**2)
Reck_4_O_res = simplify(Abs(Reck_4_O.rewrite(sin))**2)
Reck_4_P_res = simplify(Abs(Reck_4_P.rewrite(sin))**2)

display(Reck_4_A_res)
display(Reck_4_B_res)
display(Reck_4_C_res)
display(Reck_4_D_res)
display(Reck_4_E_res)
display(Reck_4_F_res)
display(Reck_4_G_res)
display(Reck_4_H_res)
display(Reck_4_I_res)
display(Reck_4_J_res)
display(Reck_4_K_res)
display(Reck_4_L_res)
display(Reck_4_M_res)
display(Reck_4_N_res)
display(Reck_4_O_res)
display(Reck_4_P_res)

# %% [markdown]
# -------
# Stage 4
# -------

# %%
#Summary
Reck_2 = [Reck_2_A_res, Reck_2_B_res, Reck_2_C_res, Reck_2_D_res]
Reck_3 = [Reck_3_A_res,Reck_3_B_res,Reck_3_C_res,Reck_3_D_res,Reck_3_E_res,Reck_3_F_res,Reck_3_G_res,Reck_3_H_res,Reck_3_I_res]
Reck_4 = [Reck_4_A_res,Reck_4_B_res,Reck_4_C_res,Reck_4_D_res,Reck_4_E_res,Reck_4_F_res,Reck_4_G_res,Reck_4_H_res,Reck_4_I_res,Reck_4_J_res,Reck_4_K_res,Reck_4_L_res,Reck_4_M_res,Reck_4_N_res,Reck_4_O_res,Reck_4_P_res]

Clements_2 = [Clements_2_A_res, Clements_2_B_res, Clements_2_C_res, Clements_2_D_res]
Clements_3 = [Clements_3_A_res,Clements_3_B_res,Clements_3_C_res,Clements_3_D_res,Clements_3_E_res,Clements_3_F_res,Clements_3_G_res,Clements_3_H_res,Clements_3_I_res]
Clements_4 = [Clements_4_A_res,Clements_4_B_res,Clements_4_C_res,Clements_4_D_res,Clements_4_E_res,Clements_4_F_res,Clements_4_G_res,Clements_4_H_res,Clements_4_I_res,Clements_4_J_res,Clements_4_K_res,Clements_4_L_res,Clements_4_M_res,Clements_4_N_res,Clements_4_O_res,Clements_4_P_res]

# %% [markdown]
# All results:
#
# Reck_2
#
#
#
# Reck_3
#
#
#
# Reck_4
#
#
#
# Clements_2
#
#
#
# Clements_3
#
#
#
# Clements_4

# %% [markdown]
# Reference for indexing letters
#
# The unitary matrix for a 2 mode Reck/Clements scheme is a 2x2 matrix and so would be of the form:
# $$
# \left(\begin{array}{cc}
# A & B\\
# C & D
# \end{array}\right)
# $$
#
# And so forth for larger matrices. You will want to index specific terms in the matrix based on the input and output mode you are after. So if your input photons are in top mode ([1,0] as column vector) and output is top mode ([1,0]) then you will want to index A and so for a Reck scheme you will want Reck_2_A_res for the transition probability; if input is top mode and output is bottom mode ([0,1]) then you will want to index C and so want Reck_2_C_res and so on.
