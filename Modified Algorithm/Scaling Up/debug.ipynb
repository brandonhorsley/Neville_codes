# %%
"""
VScode jupyter is having an issue with sympy converter jupyter notebook which may be due to the file being too big, 
so am copying over essentials to this one to continue working on it and see if that resolves issue.

nvm seems to happen to this one too :(
"""
# Out:
# '\nVScode jupyter is having an issue with sympy converter jupyter notebook which may be due to the file being too big, \nso am copying over essentials to this one to continue working on it and see if that resolves issue.\n\nnvm seems to happen to this one too :(\n'

# %%
#Copy output into a sympy expression explicitly
#N.B. Need to replace 'i' with 'I' and remove {} for multicharacter subscript, done manually or using find & replace.

from sympy import *

#symbols definition, could maybe do this like lambda expression in Calculator code?
theta_0, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10, theta_11, phi_0, phi_1, phi_2, phi_3, phi_4, phi_5, phi_6, phi_7, phi_8, phi_9, phi_10, phi_11 = symbols('theta_0 theta_1 theta_2 theta_3 theta_4 theta_5 theta_6 theta_7 theta_8 theta_9 theta_10 theta_11 phi_0 phi_1 phi_2 phi_3 phi_4 phi_5 phi_6 phi_7 phi_8 phi_9 phi_10 phi_11',real=True)
init_printing()

#Clements

#N=2
Clements_2_A = (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
Clements_2_B = I*(exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)
Clements_2_C = I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))
Clements_2_D = -exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) + cos(theta_0/2)*cos(theta_1/2)

#N=3
Clements_3_A = ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Clements_3_B = I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Clements_3_C = -(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))
Clements_3_D = I*((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))
Clements_3_E = ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2)
Clements_3_F = I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(-exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) + cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)
Clements_3_G = -(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Clements_3_H = -I*(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Clements_3_I = -exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) + cos(theta_2/2)*cos(theta_3/2)

#N=4
Clements_4_A = ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*cos(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*sin(theta_7/2))*exp(I*phi_7)
Clements_4_B = I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*cos(theta_7/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*sin(theta_7/2))*exp(I*phi_7)
Clements_4_C = -(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*exp(I*(phi_3 + phi_5 + phi_7))
Clements_4_D = -I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*exp(I*(phi_3 + phi_5 + phi_7))
Clements_4_E = I*(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*sin(theta_11/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*cos(theta_11/2))*exp(I*phi_11)
Clements_4_F = ((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(-exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) + sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*sin(theta_11/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*cos(theta_11/2))*exp(I*phi_11)
Clements_4_G = I*(-((((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) + (-(((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Clements_4_H = (((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - (-(((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Clements_4_I = ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*cos(theta_11/2) + ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*sin(theta_11/2)
Clements_4_J = I*(-(((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*sin(theta_10/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2))*cos(theta_11/2) + (-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*sin(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_6/2))*exp(I*phi_6)*sin(theta_7/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_4/2)*sin(theta_5/2))*exp(I*phi_5)*cos(theta_6/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_6/2))*cos(theta_7/2))*cos(theta_10/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*cos(theta_8/2)*cos(theta_9/2) - sin(theta_8/2)*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2))*exp(I*phi_10)*sin(theta_11/2))
Clements_4_K = ((((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) + (-(((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2)
Clements_4_L = I*(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*(exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) - cos(theta_6/2)*cos(theta_7/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2))
Clements_4_M = -I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*sin(theta_9/2)*cos(theta_8/2) + sin(theta_8/2)*cos(theta_9/2))
Clements_4_N = (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_4)*sin(theta_5/2)*cos(theta_4/2) + sin(theta_4/2)*cos(theta_5/2))*(exp(I*phi_8)*sin(theta_9/2)*cos(theta_8/2) + sin(theta_8/2)*cos(theta_9/2))
Clements_4_O = I*(-((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) + ((exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2))
Clements_4_P = ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) - ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2)

#Reck

#N=2
Reck_2_A = (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
Reck_2_B = I*(exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)
Reck_2_C = I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))
Reck_2_D = -exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) + cos(theta_0/2)*cos(theta_1/2)

#N=3
Reck_3_A = ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Reck_3_B = I*((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)
Reck_3_C = -(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))
Reck_3_D = I*((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))
Reck_3_E = ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2)
Reck_3_F = I*(exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(-exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) + cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)
Reck_3_G = -(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Reck_3_H = -I*(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))
Reck_3_I = -exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) + cos(theta_2/2)*cos(theta_3/2)

#N=4
Reck_4_A = ((-(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - ((-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Reck_4_B = I*((-((-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - (((-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(-exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) + sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Reck_4_C = -(-((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - (-(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*cos(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - (-(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*sin(theta_11/2))*exp(I*phi_11)
Reck_4_D = -I*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(exp(I*phi_8)*sin(theta_8/2)*cos(theta_9/2) + sin(theta_9/2)*cos(theta_8/2))*(exp(I*phi_10)*sin(theta_10/2)*cos(theta_11/2) + sin(theta_11/2)*cos(theta_10/2))*exp(I*(phi_7 + phi_9 + phi_11))
Reck_4_E = I*((-(-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) + ((-(((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2) + (((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + ((-(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*cos(theta_11/2))
Reck_4_F = (((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) + (((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - (((((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) - (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) - ((-((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) - (((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*cos(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*sin(theta_5/2))*exp(I*phi_5)*sin(theta_10/2))*cos(theta_11/2)
Reck_4_G = I*(((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*sin(theta_10/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*cos(theta_10/2))*exp(I*phi_10)*sin(theta_11/2) - ((((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*cos(theta_9/2) + ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*sin(theta_9/2))*exp(I*phi_9)*cos(theta_10/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)*cos(theta_4/2))*exp(I*(phi_3 + phi_5))*sin(theta_10/2))*cos(theta_11/2))
Reck_4_H = (exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(exp(I*phi_8)*sin(theta_8/2)*cos(theta_9/2) + sin(theta_9/2)*cos(theta_8/2))*(exp(I*phi_10)*sin(theta_10/2)*sin(theta_11/2) - cos(theta_10/2)*cos(theta_11/2))*exp(I*(phi_7 + phi_9))
Reck_4_I = ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) - (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*cos(theta_9/2) + ((((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) - (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) - ((exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*sin(theta_9/2)
Reck_4_J = I*(-(((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*sin(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2))*cos(theta_9/2) + (-((-(exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*sin(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*cos(theta_4/2))*exp(I*phi_4)*sin(theta_5/2) + ((exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*cos(theta_2/2)*cos(theta_3/2) - sin(theta_2/2)*sin(theta_3/2))*exp(I*phi_3)*cos(theta_4/2) + (exp(I*phi_0)*sin(theta_0/2)*cos(theta_1/2) + sin(theta_1/2)*cos(theta_0/2))*exp(I*phi_1)*sin(theta_4/2))*cos(theta_5/2))*cos(theta_8/2) + (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2))*exp(I*phi_8)*sin(theta_9/2))
Reck_4_K = ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*sin(theta_8/2) + (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*cos(theta_8/2))*exp(I*phi_8)*sin(theta_9/2) - ((exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*cos(theta_6/2)*cos(theta_7/2) - sin(theta_6/2)*sin(theta_7/2))*exp(I*phi_7)*cos(theta_8/2) - (exp(I*phi_2)*sin(theta_2/2)*cos(theta_3/2) + sin(theta_3/2)*cos(theta_2/2))*(exp(I*phi_4)*sin(theta_4/2)*sin(theta_5/2) - cos(theta_4/2)*cos(theta_5/2))*exp(I*phi_3)*sin(theta_8/2))*cos(theta_9/2)
Reck_4_L = I*(exp(I*phi_6)*sin(theta_6/2)*cos(theta_7/2) + sin(theta_7/2)*cos(theta_6/2))*(-exp(I*phi_8)*sin(theta_8/2)*sin(theta_9/2) + cos(theta_8/2)*cos(theta_9/2))*exp(I*phi_7)
Reck_4_M = -I*(exp(I*phi_0)*sin(theta_1/2)*cos(theta_0/2) + sin(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
Reck_4_N = (exp(I*phi_0)*sin(theta_0/2)*sin(theta_1/2) - cos(theta_0/2)*cos(theta_1/2))*(exp(I*phi_2)*sin(theta_3/2)*cos(theta_2/2) + sin(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
Reck_4_O = -I*(exp(I*phi_2)*sin(theta_2/2)*sin(theta_3/2) - cos(theta_2/2)*cos(theta_3/2))*(exp(I*phi_6)*sin(theta_7/2)*cos(theta_6/2) + sin(theta_6/2)*cos(theta_7/2))
Reck_4_P = -exp(I*phi_6)*sin(theta_6/2)*sin(theta_7/2) + cos(theta_6/2)*cos(theta_7/2)

# %%
from sympy import *

#symbols definition, could maybe do this like lambda expression in Calculator code?
theta_0, theta_1, theta_2, theta_3, theta_4, theta_5, theta_6, theta_7, theta_8, theta_9, theta_10, theta_11, phi_0, phi_1, phi_2, phi_3, phi_4, phi_5, phi_6, phi_7, phi_8, phi_9, phi_10, phi_11 = symbols('theta_0 theta_1 theta_2 theta_3 theta_4 theta_5 theta_6 theta_7 theta_8 theta_9 theta_10 theta_11 phi_0 phi_1 phi_2 phi_3 phi_4 phi_5 phi_6 phi_7 phi_8 phi_9 phi_10 phi_11',real=True)
init_printing()

#Test window
expr=(exp(I*phi_0)*cos(theta_0/2)*cos(theta_1/2) - sin(theta_0/2)*sin(theta_1/2))*exp(I*phi_1)
abs(expr.rewrite(sin))
# Out:
#    _____________________     _________________________________________________
#   ╱    2          2         ╱    2        ⎛θ₀   π⎞    ⎛θ₁   π⎞    ⎛θ₀⎞    ⎛θ₁⎞
# ╲╱  sin (φ₁) + cos (φ₁) ⋅  ╱  sin (φ₀)⋅sin⎜── + ─⎟⋅sin⎜── + ─⎟⋅cos⎜──⎟⋅cos⎜──⎟
#                          ╲╱               ⎝2    2⎠    ⎝2    2⎠    ⎝2 ⎠    ⎝2 ⎠
#
# ______________________________________________________________________________
#                 ⎛θ₀⎞    ⎛θ₁⎞    ⎛θ₀   π⎞    ⎛θ₁   π⎞                ⎛θ₀⎞    ⎛θ
#  - ⅈ⋅sin(φ₀)⋅sin⎜──⎟⋅sin⎜──⎟⋅sin⎜── + ─⎟⋅sin⎜── + ─⎟ + ⅈ⋅sin(φ₀)⋅sin⎜──⎟⋅sin⎜─
#                 ⎝2 ⎠    ⎝2 ⎠    ⎝2    2⎠    ⎝2    2⎠                ⎝2 ⎠    ⎝2
#
# ______________________________________________________________________________
# ₁⎞    ⎛θ₀⎞    ⎛θ₁⎞      2⎛θ₀⎞    2⎛θ₁⎞      ⎛θ₀⎞    ⎛θ₁⎞    ⎛θ₀   π⎞    ⎛θ₁
# ─⎟⋅cos⎜──⎟⋅cos⎜──⎟ + sin ⎜──⎟⋅sin ⎜──⎟ - sin⎜──⎟⋅sin⎜──⎟⋅sin⎜── + ─⎟⋅sin⎜── +
#  ⎠    ⎝2 ⎠    ⎝2 ⎠       ⎝2 ⎠     ⎝2 ⎠      ⎝2 ⎠    ⎝2 ⎠    ⎝2    2⎠    ⎝2
#
# ...

# %%
#Clements_2_A_res = simplify(Abs(Clements_2_A.rewrite(sin))**2) #0.8s
#Clements_2_B_res = simplify(Abs(Clements_2_B.rewrite(sin))**2) #0.4s
#Clements_2_C_res = simplify(Abs(Clements_2_C.rewrite(sin))**2) #0.4s
Clements_2_D_res = simplify(Abs(Clements_2_D.rewrite(sin))**2) #0.3s

#Clements_3_A_res = simplify(Abs(Clements_3_A.rewrite(sin))**2) #334m20
#Clements_3_B_res = simplify(Abs(Clements_3_B.rewrite(sin))**2) #303m45
#Clements_3_C_res = simplify(Abs(Clements_3_C.rewrite(sin))**2) #4.0s
#Clements_3_D_res = simplify(Abs(Clements_3_D.rewrite(sin))**2) #333m32
#Clements_3_E_res = simplify(Abs(Clements_3_E.rewrite(sin))**2) #316m8
#Clements_3_F_res = simplify(Abs(Clements_3_F.rewrite(sin))**2) #1.0s
#Clements_3_G_res = simplify(Abs(Clements_3_G.rewrite(sin))**2) #0.8s
#Clements_3_H_res = simplify(Abs(Clements_3_H.rewrite(sin))**2) #1.1s
#Clements_3_I_res = simplify(Abs(Clements_3_I.rewrite(sin))**2) #0.4s

#display(Clements_3_A_res) #result is unfeasible to write in pymc, way too many lines for the expression, need to find a way to just unify sympy and the pymc code so i don't have to write in the expression manually for pymc
print_python(Clements_2_D_res)
#print_python(Clements_3_E_res)
# Out:
# theta_0 = Symbol('theta_0')
# theta_1 = Symbol('theta_1')
# phi_0 = Symbol('phi_0')
# e = cos(theta_0 - theta_1)/4 + cos(theta_0 + theta_1)/4 + cos(-phi_0 + theta_0 + theta_1)/8 - cos(phi_0 - theta_0 + theta_1)/8 - cos(phi_0 + theta_0 - theta_1)/8 + cos(phi_0 + theta_0 + theta_1)/8 + Rational(1, 2)

# %%
#Clements_2_A_res
theta_0 = Symbol('theta_0')
theta_1 = Symbol('theta_1')
phi_0 = Symbol('phi_0')
e = -sin(theta_0)*sin(theta_1)*cos(phi_0)/2 + cos(theta_0)*cos(theta_1)/2 + Rational(1, 2)

#Clements_2_B_res
theta_0 = Symbol('theta_0')
theta_1 = Symbol('theta_1')
phi_0 = Symbol('phi_0')
e = sin(theta_0)*sin(theta_1)*cos(phi_0)/2 - cos(theta_0)*cos(theta_1)/2 + Rational(1, 2)

#Clements_2_C_res
theta_0 = Symbol('theta_0')
theta_1 = Symbol('theta_1')
phi_0 = Symbol('phi_0')
e = -cos(theta_0 - theta_1)/4 - cos(theta_0 + theta_1)/4 - cos(-phi_0 + theta_0 + theta_1)/8 + cos(phi_0 - theta_0 + theta_1)/8 + cos(phi_0 + theta_0 - theta_1)/8 - cos(phi_0 + theta_0 + theta_1)/8 + Rational(1, 2)

#Clements_2_D_res
theta_0 = Symbol('theta_0')
theta_1 = Symbol('theta_1')
phi_0 = Symbol('phi_0')
e = cos(theta_0 - theta_1)/4 + cos(theta_0 + theta_1)/4 + cos(-phi_0 + theta_0 + theta_1)/8 - cos(phi_0 - theta_0 + theta_1)/8 - cos(phi_0 + theta_0 - theta_1)/8 + cos(phi_0 + theta_0 + theta_1)/8 + Rational(1, 2)



#Clements_3_A_res:
phi_0 = Symbol('phi_0')
phi_1 = Symbol('phi_1')
theta_0 = Symbol('theta_0')
theta_4 = Symbol('theta_4')
theta_5 = Symbol('theta_5')
phi_2 = Symbol('phi_2')
phi_3 = Symbol('phi_3')
phi_4 = Symbol('phi_4')
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
theta_1 = Symbol('theta_1')
e = -4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_2)*cos(phi_3)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_2 + phi_3) + 4*sin(phi_0)*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 4*sin(phi_0)*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(phi_1)*sin(phi_2)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) + 4*sin(phi_1)*sin(phi_2)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) - 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 2*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_5/2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_0 + phi_2 + phi_3) + 2*sin(phi_1)*sin(phi_4)*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*sin(phi_0 - phi_3)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_2)*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 - phi_3)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_3)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_0 + phi_1 - phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_3)*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) - 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2 + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3) - 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) + 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) + 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3 + phi_4) + 4*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_3)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 - phi_2) + 4*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) - 2*sin(theta_0/2)*sin(theta_4/2)*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) + 2*sin(theta_0/2)*sin(theta_5/2)*sin(phi_0 - phi_2)*sin(phi_1 + phi_4)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(theta_0/2)*sin(theta_5/2)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_0 - phi_2)*cos(phi_3 - phi_4) - 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 + 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 4*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_1/2)**2*sin(theta_4/2)**2 + 4*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_1/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2 - 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) - 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) + 4*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_4/2)**2 - 2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_5/2)**2 + 1

#Clements_3_B_res

phi_0 = Symbol('phi_0')
phi_1 = Symbol('phi_1')
theta_0 = Symbol('theta_0')
theta_4 = Symbol('theta_4')
theta_5 = Symbol('theta_5')
phi_4 = Symbol('phi_4')
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
phi_3 = Symbol('phi_3')
theta_1 = Symbol('theta_1')
e = 4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) + 4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_2 + phi_3) - 2*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_0)*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 2*sin(phi_0)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 2*sin(phi_0)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_2 + phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 + phi_4) + 2*sin(phi_1)*sin(phi_2)*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) + 2*sin(phi_1)*sin(phi_2)*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) + 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) + 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) - 2*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_1)*sin(phi_4)*sin(theta_1/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*cos(phi_0)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_2)*sin(phi_3)*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 - phi_3)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*sin(phi_1 - phi_3)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*sin(phi_0 - phi_3)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*sin(phi_0 - phi_3)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 4*sin(phi_3)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_3)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_3)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_0 - phi_2) + 2*sin(phi_3)*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2 - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3) - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3) + 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) - 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) - 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3 + phi_4) - 4*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_3)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 - phi_2) - 4*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) + 2*sin(theta_0/2)*sin(theta_4/2)*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) + 2*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 - 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 4*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_1/2)**2*sin(theta_4/2)**2 - 4*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_1/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2 + 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) - 4*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) - 4*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_2/2)**2*sin(theta_4/2)**2 - 2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_2/2)**2*sin(theta_5/2)**2 + 4*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_3/2)**2*sin(theta_4/2)**2 - 2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_3/2)**2*sin(theta_5/2)**2 - 2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_4/2)**2 + 2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)**2

#Clements_3_C_res

theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
theta_4 = Symbol('theta_4')
theta_5 = Symbol('theta_5')
phi_4 = Symbol('phi_4')
e = (-2*cos(theta_2 - theta_3) - 2*cos(theta_2 + theta_3) - cos(-phi_2 + theta_2 + theta_3) + cos(phi_2 - theta_2 + theta_3) + cos(phi_2 + theta_2 - theta_3) - cos(phi_2 + theta_2 + theta_3) + 4)*(-2*cos(theta_4 - theta_5) - 2*cos(theta_4 + theta_5) - cos(-phi_4 + theta_4 + theta_5) + cos(phi_4 - theta_4 + theta_5) + cos(phi_4 + theta_4 - theta_5) - cos(phi_4 + theta_4 + theta_5) + 4)/64

#Clements_3_D_res

phi_0 = Symbol('phi_0')
phi_1 = Symbol('phi_1')
theta_0 = Symbol('theta_0')
theta_4 = Symbol('theta_4')
theta_5 = Symbol('theta_5')
phi_4 = Symbol('phi_4')
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
phi_3 = Symbol('phi_3')
theta_1 = Symbol('theta_1')
e = 4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) + 4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_2 + phi_3) - 2*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_0)*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 2*sin(phi_0)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 2*sin(phi_0)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_2 + phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 + phi_4) + 2*sin(phi_1)*sin(phi_2)*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) + 2*sin(phi_1)*sin(phi_2)*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) + 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) + 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) - 2*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_1)*sin(phi_4)*sin(theta_1/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*cos(phi_0)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_2)*sin(phi_3)*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 - phi_3)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*sin(phi_1 - phi_3)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*sin(phi_0 - phi_3)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*sin(phi_0 - phi_3)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 4*sin(phi_3)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_3)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_3)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_0 - phi_2) + 2*sin(phi_3)*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2*sin(theta_2/2)**2 - 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2*sin(theta_3/2)**2 + 4*sin(theta_0/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_4/2)**2 - 4*sin(theta_0/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2 - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3) - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3) + 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) - 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) - 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3 + phi_4) - 4*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_3)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 - phi_2) - 4*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) + 2*sin(theta_0/2)*sin(theta_4/2)*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) + 2*sin(theta_0/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2*sin(theta_2/2)**2 - 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2*sin(theta_3/2)**2 + 4*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_1/2)**2*sin(theta_4/2)**2 - 4*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_1/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2 + 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) - 4*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) - 4*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) - 2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_4/2)**2 + 2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_5/2)**2

#Clements_3_E_res

phi_0 = Symbol('phi_0')
phi_1 = Symbol('phi_1')
theta_0 = Symbol('theta_0')
theta_4 = Symbol('theta_4')
theta_5 = Symbol('theta_5')
phi_2 = Symbol('phi_2')
phi_3 = Symbol('phi_3')
phi_4 = Symbol('phi_4')
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
theta_1 = Symbol('theta_1')
e = -4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_2)*cos(phi_3)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) + 2*sin(phi_0)*sin(phi_1)*sin(theta_0/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_2 + phi_3) + 4*sin(phi_0)*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 4*sin(phi_0)*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 4*sin(phi_1)*sin(phi_2)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) + 4*sin(phi_1)*sin(phi_2)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_3 - phi_4) - 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 2*sin(phi_1)*sin(phi_4)*sin(theta_0/2)*sin(theta_5/2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_0 + phi_2 + phi_3) + 2*sin(phi_1)*sin(phi_4)*sin(theta_1/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 + phi_3) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 4*sin(phi_2)*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_2)*sin(theta_0/2)*sin(theta_4/2)*sin(phi_0 - phi_3)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_2)*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 - phi_3)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 4*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_3)*sin(theta_0/2)*sin(theta_4/2)*sin(phi_0 + phi_1)*cos(phi_2)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2) - 2*sin(phi_3)*sin(theta_0/2)*sin(theta_5/2)*sin(phi_0 + phi_1 - phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(phi_3)*sin(theta_1/2)*sin(theta_5/2)*sin(phi_1 + phi_4)*cos(phi_2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_3/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)**2 - 8*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)**2*sin(theta_1/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_1/2)**2 + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) - 8*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)**2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) - 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2 + 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 - 2*sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_0/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2*sin(theta_2/2)**2 + 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_0/2)**2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 2*sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_0/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + sin(theta_0/2)**2*sin(theta_3/2)**2 - 4*sin(theta_0/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_0/2)**2*sin(theta_4/2)**2 + 4*sin(theta_0/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_0/2)**2*sin(theta_5/2)**2 - sin(theta_0/2)**2 + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3) + 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_1 - phi_3) - 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) - 8*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_4/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_0/2)*sin(theta_1/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_1)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_3/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_2)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*cos(phi_0)*cos(phi_2)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 2*sin(theta_0/2)*sin(theta_1/2)*sin(theta_3/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) + 8*sin(theta_0/2)*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_0)*cos(phi_4)*cos(theta_0/2)*cos(theta_1/2)*cos(theta_4/2)*cos(theta_5/2) + 4*sin(theta_0/2)*sin(theta_1/2)*sin(theta_5/2)**2*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 2*sin(theta_0/2)*sin(theta_1/2)*cos(phi_0)*cos(theta_0/2)*cos(theta_1/2) - 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3) - 4*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) + 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_0/2)*cos(theta_4/2)*cos(phi_0 + phi_1 - phi_3) + 2*sin(theta_0/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_0/2)*cos(theta_5/2)*cos(phi_0 + phi_1 - phi_3 + phi_4) + 4*sin(theta_0/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_0)*cos(phi_3)*cos(phi_4)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_1 - phi_2) + 4*sin(theta_0/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) - 2*sin(theta_0/2)*sin(theta_4/2)*cos(phi_0)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(phi_1 - phi_2) + 2*sin(theta_0/2)*sin(theta_5/2)*sin(phi_0 - phi_2)*sin(phi_1 + phi_4)*cos(phi_3)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2) - 2*sin(theta_0/2)*sin(theta_5/2)*cos(phi_1)*cos(theta_0/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_0 - phi_2)*cos(phi_3 - phi_4) - 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 + 4*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_3/2)**2 + 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)**2 - 2*sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_1/2)**2*sin(theta_2/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2*sin(theta_2/2)**2 + 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 4*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_1/2)**2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 2*sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_1/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + sin(theta_1/2)**2*sin(theta_3/2)**2 - 4*sin(theta_1/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + 2*sin(theta_1/2)**2*sin(theta_4/2)**2 + 4*sin(theta_1/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_1/2)**2*sin(theta_5/2)**2 - sin(theta_1/2)**2 - 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3) - 4*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_4/2)*cos(phi_1 - phi_3) + 2*sin(theta_1/2)*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)*cos(theta_1/2)*cos(theta_5/2)*cos(phi_1 - phi_3 + phi_4) + 4*sin(theta_1/2)*sin(theta_4/2)**2*sin(theta_5/2)*cos(phi_4)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(-phi_1 + phi_2 + phi_3) + 4*sin(theta_1/2)*sin(theta_4/2)*sin(theta_5/2)**2*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 2*sin(theta_1/2)*sin(theta_4/2)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(-phi_1 + phi_2 + phi_3) - 2*sin(theta_1/2)*sin(theta_5/2)*cos(phi_1)*cos(phi_3)*cos(theta_1/2)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_5/2)*cos(phi_2 - phi_4) + 4*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 - 2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)**2 - 4*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - 2*sin(theta_2/2)**2*sin(theta_3/2)**2*sin(theta_5/2)**2 + 2*sin(theta_2/2)**2*sin(theta_3/2)**2 - 2*sin(theta_2/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_2/2)**2*sin(theta_4/2)**2 + 2*sin(theta_2/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_2/2)**2*sin(theta_5/2)**2 - sin(theta_2/2)**2 - 4*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) + 4*sin(theta_2/2)*sin(theta_3/2)*sin(theta_4/2)*sin(theta_5/2)*cos(phi_2)*cos(phi_4)*cos(theta_2/2)*cos(theta_3/2)*cos(theta_4/2)*cos(theta_5/2) + 2*sin(theta_2/2)*sin(theta_3/2)*sin(theta_5/2)**2*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_2/2)*sin(theta_3/2)*cos(phi_2)*cos(theta_2/2)*cos(theta_3/2) - 2*sin(theta_3/2)**2*sin(theta_4/2)**2*sin(theta_5/2)**2 + sin(theta_3/2)**2*sin(theta_4/2)**2 + 2*sin(theta_3/2)**2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) + sin(theta_3/2)**2*sin(theta_5/2)**2 - sin(theta_3/2)**2 + 2*sin(theta_4/2)**2*sin(theta_5/2)**2 - sin(theta_4/2)**2 - 2*sin(theta_4/2)*sin(theta_5/2)*cos(phi_4)*cos(theta_4/2)*cos(theta_5/2) - sin(theta_5/2)**2 + 1

#Clements_3_F_res

theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
theta_4 = Symbol('theta_4')
theta_5 = Symbol('theta_5')
phi_4 = Symbol('phi_4')
e = (-2*cos(theta_2 - theta_3) - 2*cos(theta_2 + theta_3) - cos(-phi_2 + theta_2 + theta_3) + cos(phi_2 - theta_2 + theta_3) + cos(phi_2 + theta_2 - theta_3) - cos(phi_2 + theta_2 + theta_3) + 4)*(2*cos(theta_4 - theta_5) + 2*cos(theta_4 + theta_5) + cos(-phi_4 + theta_4 + theta_5) - cos(phi_4 - theta_4 + theta_5) - cos(phi_4 + theta_4 - theta_5) + cos(phi_4 + theta_4 + theta_5) + 4)/64

#Clements_3_G_res

theta_0 = Symbol('theta_0')
theta_1 = Symbol('theta_1')
phi_0 = Symbol('phi_0')
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
e = (-2*cos(theta_0 - theta_1) - 2*cos(theta_0 + theta_1) - cos(-phi_0 + theta_0 + theta_1) + cos(phi_0 - theta_0 + theta_1) + cos(phi_0 + theta_0 - theta_1) - cos(phi_0 + theta_0 + theta_1) + 4)*(-2*cos(theta_2 - theta_3) - 2*cos(theta_2 + theta_3) - cos(-phi_2 + theta_2 + theta_3) + cos(phi_2 - theta_2 + theta_3) + cos(phi_2 + theta_2 - theta_3) - cos(phi_2 + theta_2 + theta_3) + 4)/64

#Clements_3_H_res

theta_0 = Symbol('theta_0')
theta_1 = Symbol('theta_1')
phi_0 = Symbol('phi_0')
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
e = (2*cos(theta_0 - theta_1) + 2*cos(theta_0 + theta_1) + cos(-phi_0 + theta_0 + theta_1) - cos(phi_0 - theta_0 + theta_1) - cos(phi_0 + theta_0 - theta_1) + cos(phi_0 + theta_0 + theta_1) + 4)*(-2*cos(theta_2 - theta_3) - 2*cos(theta_2 + theta_3) - cos(-phi_2 + theta_2 + theta_3) + cos(phi_2 - theta_2 + theta_3) + cos(phi_2 + theta_2 - theta_3) - cos(phi_2 + theta_2 + theta_3) + 4)/64

#Clements_3_I_res
theta_2 = Symbol('theta_2')
theta_3 = Symbol('theta_3')
phi_2 = Symbol('phi_2')
e = cos(theta_2 - theta_3)/4 + cos(theta_2 + theta_3)/4 + cos(-phi_2 + theta_2 + theta_3)/8 - cos(phi_2 - theta_2 + theta_3)/8 - cos(phi_2 + theta_2 - theta_3)/8 + cos(phi_2 + theta_2 + theta_3)/8 + Rational(1, 2)
